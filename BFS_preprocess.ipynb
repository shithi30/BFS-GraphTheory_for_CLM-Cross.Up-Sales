# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("BFS_prep.csv") 
from_scat=list(df["from_scat"])
to_scats=list(df["to_scat"])

tuples=len(from_scat)

# %%
print("1")
print()
print(str(tuples)+" "+str(1)) # input here the number of pairs between which we want to find the shortest path
for i in range(0, tuples):
    print(from_scat[i]+" "+to_scats[i]) 

# points to find paths 
print("wash_&_iron"+" "+"refrigerator_repair_services") # input the service strings: A to B
# Out:
# 1
#
# 479 1
# transport_for_shifting ac_repair_services
# transport_for_shifting hire_a_cleaner
# transport_for_shifting packers_&_movers
# transport_for_shifting exclusive_iron_offer
# transport_for_shifting house_shifting_services
# transport_for_shifting sheba_groceries
# transport_for_shifting expert_t-shirt
# transport_for_shifting inside_city
# transport_for_shifting tv_repair_services
# transport_for_shifting health_&_hygiene
# ac_repair_services refrigerator_repair_services
# ac_repair_services electricians_for_electrical_service
# ac_repair_services microwave_oven_repair_services
# ac_repair_services plumbing_&_sanitary_services
# ac_repair_services washing_machine_repair_services
# ac_repair_services tv_repair_services
# ac_repair_services laptop_servicing
# ac_repair_services carpentry_services
# ac_repair_services sheba_groceries
# ac_repair_services desktop_services
# ambulance_service ips_repair_services
# ambulance_service sheba_groceries
# ...
